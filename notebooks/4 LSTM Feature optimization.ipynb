# %% [markdown]
# # LSTM Feature optimization

# %% [markdown]
# The purposes of this is to explore optimization for the model

# %%
import csv
import os
import sys
import numpy as np
from copy import deepcopy
from datetime import datetime
import warnings

from math import sqrt
from numpy import concatenate
from matplotlib import pyplot

from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import keras

# %%
def get_index_of_date(df, date):
    # print(date)
    x = df.index[df['DATE'] == str(date).split(' ')[0]].tolist()
    if len(x) == 0:
        print("Date: " + str(date) + " not found in dataset")
        exit(1)

    return x[0]


def output_stats_to_csv(file_location, cols_used, mae, mse, rmse, r2):
    col_names = ['int_time',
                 'int_date',
                 'int_day',
                 'rain',
                 'temp',
                 'rhum',
                 'mae',
                 'mse',
                 'rmse',
                 'r2',
                 'rmsle',
                 'timestamp'
                ]
    
    destination_directory = '../datasets/bss/dublin/feature_optimization_stats/'
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)

    destination_file = destination_directory + file_location.split('/')[-1]

    if not os.path.exists(destination_file):

        with open(destination_file, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerows([col_names])

    with open(destination_file, 'a', newline='') as csvfile:

        writer = csv.DictWriter(csvfile, fieldnames=col_names)

        writer.writerow({
            'int_time': ('int_time' in cols_used),
            'int_date': ('int_date' in cols_used),
            'int_day': ('int_day' in cols_used),
            'rain': ('rain' in cols_used),
            'temp': ('temp' in cols_used),
            'rhum': ('rhum' in cols_used),
            'mae': mae,
            'mse': mse,
            'rmse': rmse,
            'r2': r2,
            'timestamp': datetime.now().strftime("%d/%m/%Y %H:%M:%S")
        })

# %% [markdown]
# This is a modified version of the model used to more easily use different combonations

# %%
def train_model(file_location,
                train_start_date=datetime(year=2018, month=8, day=1),
                train_end_date=datetime(year=2019, month=7, day=30),
                test_start_date=datetime(year=2019, month=8, day=1),
                test_end_date=datetime(year=2019, month=12, day=31),
                cols_to_use=None,
                verbose=1
                ):
    if cols_to_use is None:
        cols_to_use = ['int_time', 'int_date', 'int_day']

    cols_to_use.insert(0, 'AVAILABLE BIKES')
    cols_to_use.insert(0, 'TIME')
    
    # load dataset
    dataset = read_csv(file_location, usecols=cols_to_use)
    dataset['DATE'] = dataset['TIME'].apply(lambda x: x.split(' ')[0])

    # Rain causes datatype problems if not dealt with
    if 'rain' in cols_to_use:
        dataset = dataset[dataset['rain'].str.strip().astype(bool)]

    train_start_index = (get_index_of_date(dataset, train_start_date))
    train_end_index = (get_index_of_date(dataset, train_end_date))

    test_start_index = (get_index_of_date(dataset, test_start_date))
    test_end_index = (get_index_of_date(dataset, test_end_date))

    dataset = dataset.drop(['TIME', 'DATE'], axis=1)
    values = dataset.values

    # ensure all data is float
    values = values.astype('float32')
    
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)

    # split into train and test sets
    train = scaled[train_start_index:train_end_index, :]
    test = scaled[test_start_index:test_end_index, :]
    # train = values[train_start:train_end, :]
    # test = values[test_start:test_end, :]

    # split into input and outputs
    train_X, train_y = train[:, 1:], train[:, 0]
    test_X, test_y = test[:, 1:], test[:, 0]
    
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

    # design network
    model = Sequential()
    model.add(LSTM(40, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error')


    # fit network
    history = model.fit(train_X, train_y,
                        epochs=150,
                        batch_size=64,
                        validation_data=(test_X, test_y),
                        verbose=verbose,
                        shuffle=False)

    # make a prediction
    yhat = model.predict(test_X)
    test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
    
    # invert scaling for forecast
    inv_yhat = concatenate((yhat, test_X), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:, 0]
    
    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = concatenate((test_y, test_X), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:, 0]

    rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
    mae = mean_absolute_error(inv_y, inv_yhat)
    mse = mean_squared_error(inv_y, inv_yhat)
    r2 = r2_score(inv_y, inv_yhat)
    
    print('Test MAE: %.3f' % mae)
    print('Test MSE: %.3f' % mse)
    print('Test RMSE: %.3f' % rmse)
    print('Test R2: %.3f' % r2)

    output_stats_to_csv(file_location, cols_to_use, mae, mse, rmse, r2)

# %%
def powerset(s):
    x = len(s)
    masks = [1 << i for i in range(x)]
    for i in range(1 << x):
        yield [ss for mask, ss in zip(masks, s) if i & mask]


def test_powersets(start_position=0,
                   file='../datasets/bss/dublin/reorg_plus_weather/station_2.csv',
                   train_start_date=None,
                   train_end_date=None,
                   test_start_date=None,
                   test_end_date=None,
                   ):
    attr_list = [
        'int_time',
        'int_date',
        'int_day',
        'rain',
        'temp',
        'rhum'
    ]

    y = list(powerset(attr_list))
    # y.sort()
    print(len(y))
    y = sorted(y, key=len)
    y.pop(0)

    for x in y[start_position:]:
        print(str(start_position) + "/" + str(len(y) - 1))
        start_position = start_position + 1
        print(x)
        warnings.filterwarnings("ignore")
        if train_start_date is not None and train_end_date is not None and test_start_date is not None and test_end_date is not None:
            train_model(file,
                        train_start_date=train_start_date,
                        train_end_date=train_end_date,
                        test_start_date=test_start_date,
                        test_end_date=test_end_date,
                        cols_to_use=x,
                        verbose=0)
        else:
            train_model(file,
                        cols_to_use=x,
                        verbose=0)
        print()
        keras.backend.clear_session()

# %%
test_powersets(start_position=11,
               file='../datasets/bss/dublin/reorg_plus_weather/station_30.csv')


# # Trying to predict 2020 data with older training set
# test_powersets(
#                file='../datasets/bss/dublin/reorg_plus_weather/station_4.csv',
#                train_start_date=datetime(year=2018, month=8, day=1),
#                train_end_date=datetime(year=2020, month=1, day=31),
#                test_start_date=datetime(year=2020, month=4, day=1),
#                test_end_date=datetime(year=2020, month=12, day=1),
#                )
# Out:
# 64
# 11/62
# ['int_day', 'rain']
# Test MAE: 2.580
# Test MSE: 12.449
# Test RMSE: 3.528
# Test R2: -0.011
#
# 12/62
# ['int_time', 'temp']
# Test MAE: 2.846
# Test MSE: 13.285
# Test RMSE: 3.645
# Test R2: -0.078
#
# 13/62
# ['int_date', 'temp']
# Test MAE: 2.787
# Test MSE: 12.856
# Test RMSE: 3.585
# Test R2: -0.043
#
# 14/62
# ['int_day', 'temp']
# Test MAE: 2.703
# Test MSE: 12.691
# Test RMSE: 3.562
# Test R2: -0.030
#
# 15/62
# ['rain', 'temp']
# Test MAE: 2.668
# Test MSE: 12.604
# Test RMSE: 3.550
# Test R2: -0.023
#
# 16/62
# ['int_time', 'rhum']
# Test MAE: 2.727
# Test MSE: 12.801
# Test RMSE: 3.578
# Test R2: -0.039
#
# 17/62
# ['int_date', 'rhum']
# Test MAE: 2.632
# Test MSE: 12.392
# Test RMSE: 3.520
# Test R2: -0.006
#
# 18/62
# ['int_day', 'rhum']
# Test MAE: 2.657
# Test MSE: 12.457
# Test RMSE: 3.529
# Test R2: -0.011
#
# 19/62
# ['rain', 'rhum']
# Test MAE: 2.573
# Test MSE: 12.350
# Test RMSE: 3.514
# Test R2: -0.002
#
# 20/62
# ['temp', 'rhum']
# Test MAE: 2.710
# Test MSE: 12.623
# Test RMSE: 3.553
# Test R2: -0.024
#
# 21/62
# ['int_time', 'int_date', 'int_day']
# Test MAE: 2.808
# Test MSE: 13.059
# Test RMSE: 3.614
# Test R2: -0.060
#
# 22/62
# ['int_time', 'int_date', 'rain']
# Test MAE: 2.607
# Test MSE: 12.581
# Test RMSE: 3.547
# Test R2: -0.021
#
# 23/62
# ['int_time', 'int_day', 'rain']
# Test MAE: 2.614
# Test MSE: 12.705
# Test RMSE: 3.564
# Test R2: -0.031
#
# 24/62
# ['int_date', 'int_day', 'rain']
# Test MAE: 2.508
# Test MSE: 12.430
# Test RMSE: 3.526
# Test R2: -0.009
#
# 25/62
# ['int_time', 'int_date', 'temp']
# Test MAE: 3.003
# Test MSE: 14.007
# Test RMSE: 3.743
# Test R2: -0.137
#
# 26/62
# ['int_time', 'int_day', 'temp']
# Test MAE: 2.904
# Test MSE: 13.466
# Test RMSE: 3.670
# Test R2: -0.093
#
# 27/62
# ['int_date', 'int_day', 'temp']
# Test MAE: 2.769
# Test MSE: 12.823
# Test RMSE: 3.581
# Test R2: -0.041
#
# 28/62
# ['int_time', 'rain', 'temp']
# Test MAE: 2.838
# Test MSE: 13.336
# Test RMSE: 3.652
# Test R2: -0.083
#
# 29/62
# ['int_date', 'rain', 'temp']
# Test MAE: 2.626
# Test MSE: 12.484
# Test RMSE: 3.533
# Test R2: -0.013
#
# 30/62
# ['int_day', 'rain', 'temp']
# Test MAE: 2.676
# Test MSE: 12.638
# Test RMSE: 3.555
# Test R2: -0.026
#
# 31/62
# ['int_time', 'int_date', 'rhum']
# Test MAE: 2.795
# Test MSE: 12.971
# Test RMSE: 3.602
# Test R2: -0.053
#
# 32/62
# ['int_time', 'int_day', 'rhum']
# Test MAE: 2.774
# Test MSE: 12.996
# Test RMSE: 3.605
# Test R2: -0.055
#
# 33/62
# ['int_date', 'int_day', 'rhum']
# Test MAE: 2.674
# Test MSE: 12.450
# Test RMSE: 3.528
# Test R2: -0.010
#
# 34/62
# ['int_time', 'rain', 'rhum']
# Test MAE: 2.682
# Test MSE: 12.743
# Test RMSE: 3.570
# Test R2: -0.034
#
# 35/62
# ['int_date', 'rain', 'rhum']
# Test MAE: 2.541
# Test MSE: 12.339
# Test RMSE: 3.513
# Test R2: -0.002
#
# 36/62
# ['int_day', 'rain', 'rhum']
# Test MAE: 2.590
# Test MSE: 12.460
# Test RMSE: 3.530
# Test R2: -0.011
#
# 37/62
# ['int_time', 'temp', 'rhum']
# Test MAE: 2.910
# Test MSE: 13.514
# Test RMSE: 3.676
# Test R2: -0.097
#
# 38/62
# ['int_date', 'temp', 'rhum']
# Test MAE: 2.819
# Test MSE: 12.995
# Test RMSE: 3.605
# Test R2: -0.054
#
# 39/62
# ['int_day', 'temp', 'rhum']
# Test MAE: 2.769
# Test MSE: 12.845
# Test RMSE: 3.584
# Test R2: -0.042
#
# 40/62
# ['rain', 'temp', 'rhum']
# Test MAE: 2.679
# Test MSE: 12.569
# Test RMSE: 3.545
# Test R2: -0.020
#
# 41/62
# ['int_time', 'int_date', 'int_day', 'rain']
# Test MAE: 2.619
# Test MSE: 12.593
# Test RMSE: 3.549
# Test R2: -0.022
#
# 42/62
# ['int_time', 'int_date', 'int_day', 'temp']
# Test MAE: 2.890
# Test MSE: 13.375
# Test RMSE: 3.657
# Test R2: -0.085
#
# 43/62
# ['int_time', 'int_date', 'rain', 'temp']
# Test MAE: 2.875
# Test MSE: 13.353
# Test RMSE: 3.654
# Test R2: -0.084
#
# 44/62
# ['int_time', 'int_day', 'rain', 'temp']
# Test MAE: 2.823
# Test MSE: 13.176
# Test RMSE: 3.630
# Test R2: -0.069
#
# 45/62
# ['int_date', 'int_day', 'rain', 'temp']
# Test MAE: 2.706
# Test MSE: 12.776
# Test RMSE: 3.574
# Test R2: -0.037
#
# 46/62
# ['int_time', 'int_date', 'int_day', 'rhum']
# Test MAE: 2.738
# Test MSE: 12.767
# Test RMSE: 3.573
# Test R2: -0.036
#
# 47/62
# ['int_time', 'int_date', 'rain', 'rhum']
# Test MAE: 2.622
# Test MSE: 12.663
# Test RMSE: 3.558
# Test R2: -0.028
#
# 48/62
# ['int_time', 'int_day', 'rain', 'rhum']
# Test MAE: 2.695
# Test MSE: 12.891
# Test RMSE: 3.590
# Test R2: -0.046
#
# 49/62
# ['int_date', 'int_day', 'rain', 'rhum']
# Test MAE: 2.596
# Test MSE: 12.484
# Test RMSE: 3.533
# Test R2: -0.013
#
# 50/62
# ['int_time', 'int_date', 'temp', 'rhum']
# Test MAE: 3.013
# Test MSE: 14.018
# Test RMSE: 3.744
# Test R2: -0.138
#
# 51/62
# ['int_time', 'int_day', 'temp', 'rhum']
# Test MAE: 2.957
# Test MSE: 13.683
# Test RMSE: 3.699
# Test R2: -0.110
#
# 52/62
# ['int_date', 'int_day', 'temp', 'rhum']
# Test MAE: 2.698
# Test MSE: 12.622
# Test RMSE: 3.553
# Test R2: -0.024
#
# 53/62
# ['int_time', 'rain', 'temp', 'rhum']
# Test MAE: 2.832
# Test MSE: 13.179
# Test RMSE: 3.630
# Test R2: -0.070
#
# 54/62
# ['int_date', 'rain', 'temp', 'rhum']
# Test MAE: 2.644
# Test MSE: 12.551
# Test RMSE: 3.543
# Test R2: -0.019
#
# 55/62
# ['int_day', 'rain', 'temp', 'rhum']
# Test MAE: 2.675
# Test MSE: 12.733
# Test RMSE: 3.568
# Test R2: -0.034
#
# 56/62
# ['int_time', 'int_date', 'int_day', 'rain', 'temp']
# Test MAE: 2.926
# Test MSE: 13.580
# Test RMSE: 3.685
# Test R2: -0.102
#
# 57/62
# ['int_time', 'int_date', 'int_day', 'rain', 'rhum']
# Test MAE: 2.650
# Test MSE: 12.685
# Test RMSE: 3.562
# Test R2: -0.030
#
# 58/62
# ['int_time', 'int_date', 'int_day', 'temp', 'rhum']
# Test MAE: 2.956
# Test MSE: 13.696
# Test RMSE: 3.701
# Test R2: -0.111
#
# 59/62
# ['int_time', 'int_date', 'rain', 'temp', 'rhum']
# Test MAE: 2.837
# Test MSE: 13.234
# Test RMSE: 3.638
# Test R2: -0.074
#
# 60/62
# ['int_time', 'int_day', 'rain', 'temp', 'rhum']
# Test MAE: 2.771
# Test MSE: 13.212
# Test RMSE: 3.635
# Test R2: -0.072
#
# 61/62
# ['int_date', 'int_day', 'rain', 'temp', 'rhum']
# Test MAE: 2.722
# Test MSE: 12.741
# Test RMSE: 3.569
# Test R2: -0.034
#
# 62/62
# ['int_time', 'int_date', 'int_day', 'rain', 'temp', 'rhum']
# Test MAE: 2.894
# Test MSE: 13.443
# Test RMSE: 3.666
# Test R2: -0.091

# %%
def feature_performance_deltas(file='../datasets/bss/dublin/feature_optimization_stats/station_2.csv'):
    attr_list = [
        'int_time',
        'int_date',
        'int_day',
        'rain',
        'temp',
        'rhum'
    ]
    
    stats_list = [
        'mae',
        'mse',
        'rmse',
        'r2'
    ]
    
    stats = read_csv(file)
    
    col_names = deepcopy(stats_list)
    col_names.insert(0, 'feature')
    destination_directory = '../datasets/bss/dublin/feature_optimization_deltas/'
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)

    destination_file = destination_directory + file.split('/')[-1]

    with open(destination_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows([col_names])
    
    with open(destination_file, 'a', newline='') as csvfile:
        
        writer = csv.DictWriter(csvfile, fieldnames=col_names)
        
        for attr in attr_list:
            stats_with_attr = stats[stats[attr] == True]
            stats_without_attr = stats[stats[attr] == False]
            print("--- " + attr + " ---")
            line_dict = {}
            line_dict['feature'] = attr
            for stat in stats_list:
                average_with = stats_with_attr[stat].sum() / len(stats_with_attr)
                average_without = stats_without_attr[stat].sum() / len(stats_without_attr)
                print(stat.upper())
                print("Average with: " + str(average_with))
                print("Average without: " + str(average_without))
                print("Average delta (with-without): " + str(average_with - average_without))
                line_dict[stat] = (average_with - average_without)
                print()
            
            writer.writerow(line_dict)
        
feature_performance_deltas(file='../datasets/bss/dublin/feature_optimization_stats/station_30.csv')
# Out:
# --- int_time ---
# MAE
# Average with: 2.785502040625
# Average without: 2.652153696774193
# Average delta (with-without): 0.13334834385080674
#
# MSE
# Average with: 13.10940003125
# Average without: 12.566862532258064
# Average delta (with-without): 0.5425374989919369
#
# RMSE
# Average with: 3.620226947249306
# Average without: 3.5448971094316035
# Average delta (with-without): 0.0753298378177023
#
# R2
# Average with: -0.06395688986382014
# Average without: -0.01992975518603584
# Average delta (with-without): -0.0440271346777843
#
# --- int_date ---
# MAE
# Average with: 2.72426203125
# Average without: 2.7153691903225807
# Average delta (with-without): 0.008892840927419154
#
# MSE
# Average with: 12.868233359375001
# Average without: 12.81580877419355
# Average delta (with-without): 0.05242458518145021
#
# RMSE
# Average with: 3.58663856955143
# Average without: 3.57956898318425
# Average delta (with-without): 0.007069586367179692
#
# R2
# Average with: -0.04438402996459698
# Average without: -0.040133997662653305
# Average delta (with-without): -0.004250032301943672
#
# --- int_day ---
# MAE
# Average with: 2.7256164875
# Average without: 2.713971041935484
# Average delta (with-without): 0.011645445564516077
#
# MSE
# Average with: 12.862139421875
# Average without: 12.822099290322582
# Average delta (with-without): 0.040040131552418146
#
# RMSE
# Average with: 3.585982360749542
# Average without: 3.580246360012004
# Average delta (with-without): 0.005736000737537772
#
# R2
# Average with: -0.043889889939953214
# Average without: -0.04064407768809202
# Average delta (with-without): -0.0032458122518611923
#
# --- rain ---
# MAE
# Average with: 2.679326209375
# Average without: 2.7617545548387095
# Average delta (with-without): -0.08242834546370936
#
# MSE
# Average with: 12.764346890625
# Average without: 12.923046419354842
# Average delta (with-without): -0.1586995287298425
#
# RMSE
# Average with: 3.5723971517430226
# Average without: 3.5942698015671217
# Average delta (with-without): -0.02187264982409909
#
# R2
# Average with: -0.036091425023396684
# Average without: -0.04869410598905362
# Average delta (with-without): 0.012602680965656934
#
# --- temp ---
# MAE
# Average with: 2.8015351937500004
# Average without: 2.63560334516129
# Average delta (with-without): 0.16593184858871046
#
# MSE
# Average with: 13.085720328125
# Average without: 12.591306096774193
# Average delta (with-without): 0.494414231350806
#
# RMSE
# Average with: 3.616917339842251
# Average without: 3.548313478367918
# Average delta (with-without): 0.06860386147433317
#
# R2
# Average with: -0.06203504773155731
# Average without: -0.02191359222579102
# Average delta (with-without): -0.04012145550576629
#
# --- rhum ---
# MAE
# Average with: 2.73437214375
# Average without: 2.7049329451612905
# Average delta (with-without): 0.02943919858870947
#
# MSE
# Average with: 12.86100253125
# Average without: 12.82327285483871
# Average delta (with-without): 0.037729676411290214
#
# RMSE
# Average with: 3.585734492789682
# Average without: 3.5805022237125055
# Average delta (with-without): 0.0052322690771764435
#
# R2
# Average with: -0.04379714984214102
# Average without: -0.04073980940196268
# Average delta (with-without): -0.003057340440178337
